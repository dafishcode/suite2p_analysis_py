# %%
import sys
import seaborn as sns
import os
import glob
from matplotlib import pyplot as plt
import numpy as np
import avalanches as crfn
import admin_functions as adfn
import plot as pltfn
from kuramoto1 import Kuramoto
from scipy import stats 

sns.reset_orig()
#plt.style.use('dark_background')

# %load_ext autoreload
# %autoreload

# Define paths
#---------------------------------------------------------------------------
Fdrop = '/Users/dominicburrows/Dropbox/PhD/analysis/'
Fmac = '/Users/dominicburrows/Documents/'
F10t = '/Volumes/Dominic 10tb/'
Ffig = '/Users/dominicburrows/Dropbox/PhD/figures/'
Ftm = '/Volumes/Dominic Time Machine/'
# Out:
# /Users/dominicburrows/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   self[key] = other[key]
# /Users/dominicburrows/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/dominicburrows/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]
# /Users/dominicburrows/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/dominicburrows/anaconda3/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]

# %%
# PLOT - average whole brain fluorescence
#----------------------------------------
experiment = 'PTZ-WILDTYPE'
os.chdir(F10t + 'Project/' + experiment)
liklist = sorted(glob.glob('*marglik*'))
avlist = sorted(glob.glob('*_av.npy*'))
liklist
# Out:
# []

# %%
num1 = adfn.name_zero('front', 3,6,1)
num1
# Out:
# ['03', '04', '05', '06']

# %%
for i in num1:
    avlist =  sorted(glob.glob('*-' + i + '*BLN*nnbav.npy'))[:180]
    powerlist = list(range(200))
    lognlist = list(range(200))
    for e in range(len(avlist)):
        data = np.load(avlist[e])
        sizes=data[0,:]
        M=len(sizes)
        a=min(sizes) #define xmin
        b=max(sizes) #define xmax
        npart = 2000 #number of particles - number of draws from prior distribution
        ln=IS_LN(npart)
        po=IS(npart)
        powerlist[e] = po
        lognlist[e] = ln
        print('Done param ' + str(e) + 'for fish ' + adfn.name_template([avlist[e]], 'short'))
    np.save(Fdrop + 'Project/' + experiment + os.sep + adfn.name_template([avlist[e]], 'short') + '_marglik_power.npy', powerlist)
    np.save(Fdrop + 'Project/' + experiment + os.sep + adfn.name_template([avlist[e]], 'short') + '_marglik_logn.npy', lognlist)
    print('Done fish ' + adfn.name_template([avlist[e]], 'short'))
# Out:
# Done param 0for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 1for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 2for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 3for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 4for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 5for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 6for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 7for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 8for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 9for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 10for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 11for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 12for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 13for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 14for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 15for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 16for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 17for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 18for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 19for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 20for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 21for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 22for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 23for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 24for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 25for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 26for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 27for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 28for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 29for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 30for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 31for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 32for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 33for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 34for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 35for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 36for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 37for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 38for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 39for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 40for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 41for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 42for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 43for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 44for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 45for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 46for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 47for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 48for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 49for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 50for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 51for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 52for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 53for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 54for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 55for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 56for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 57for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 58for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 59for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 60for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 61for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 62for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 63for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 64for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 65for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 66for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 67for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 68for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 69for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 70for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 71for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 72for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 73for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 74for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 75for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 76for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 77for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 78for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 79for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 80for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 81for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 82for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 83for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 84for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 85for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 86for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 87for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 88for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 89for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 90for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 91for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 92for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 93for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 94for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 95for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 96for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 97for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 98for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 99for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 100for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 101for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 102for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 103for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 104for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 105for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 106for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 107for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 108for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 109for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 110for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 111for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 112for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 113for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 114for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 115for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 116for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 117for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 118for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 119for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 120for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 121for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 122for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 123for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 124for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 125for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 126for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 127for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 128for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 129for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 130for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 131for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 132for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 133for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 134for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 135for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 136for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 137for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 138for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 139for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 140for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 141for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 142for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 143for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 144for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 145for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 146for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 147for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 148for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 149for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 150for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01
# Done param 151for fish PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01

# %%
import numpy as np 
import scipy.stats as stat
import matplotlib.pyplot as plt


#Functional form for power law
def powerlaw(n,lam):
    zeta=np.sum(1.0/np.arange(a,b+1)**lam)
    return(n**(-lam)/zeta)

#Functional form for lognormal
def lognormal(n,mu,sig):
    return(1.0/n/np.sqrt(2*np.pi*sig**2)*np.exp(-(np.log(n)-mu)**2/(2*sig**2)))


#Calculate loglikelihood for power law
def LogLikelihood(lam):
    zetamat=np.power.outer(1.0/np.arange(a,b+1),lam) 
    zeta=np.sum(zetamat,0)
    nprod=-lam*np.sum(np.log(sizes))
    norm=-M*np.log(zeta)
    loglik=nprod+norm
    return(loglik) 

#Calculate loglikelihood for lognormal
def LogLikelihood_LN(mu,sig):
    T1 = -np.sum(np.log(sizes))
    T2_mat = np.subtract.outer(np.log(sizes),mu)**2
    T2 = -np.sum(T2_mat,0)/(2*sig**2)
    T0 = -M*np.log(np.sqrt(2*np.pi) * sig )
    loglik=T0+T1+T2
    return(loglik) 

#OUTPUT - posterior average exponent, log marginal likelihood, effective sample size = number that tells you how good is your sampler, dont worry
def IS(npart):
    lambda_sample=np.random.uniform(0.1,5,npart)
    weights=LogLikelihood(lambda_sample)+stat.norm.logpdf(lambda_sample,1,3)-stat.uniform.logpdf(lambda_sample,0.1,5)
    maxw=np.max(weights)

    w2 = np.exp(weights-maxw)
    w2_sum = np.sum(w2)

    ESS=1.0/(np.sum((w2/w2_sum)**2))

    mean_lambda = np.dot(lambda_sample,w2)/w2_sum
    return([mean_lambda,maxw + np.log(np.sum(np.exp(weights-maxw)))-np.log(npart),LogLikelihood(lambda_sample), ESS])
#
def IS_LN(npart):
    mu_sample = np.random.uniform(-2.0,2.0,npart)
    sig_sample = np.random.uniform(0.1,5.0,npart)
    weights=LogLikelihood_LN(mu_sample,sig_sample)
    maxw=np.max(weights)

    w2 = np.exp(weights-maxw)
    w2_sum = np.sum(w2)

    ESS=1.0/(np.sum((w2/w2_sum)**2))

    wmax_ID=np.argmax(w2)
    mean_mu = mu_sample[wmax_ID]
    mean_sig = sig_sample[wmax_ID]

    return([mean_mu,mean_sig, maxw + np.log(np.sum(np.exp(weights-maxw)))-np.log(npart), LogLikelihood_LN(mu_sample, sig_sample), ESS])


#find entire posterior dsitr - posterior distribution - range of values 
def plot_samples(npart):
    lambda_sample=np.random.uniform(0.1,5,npart)
    weights=LogLikelihood(lambda_sample)
    maxw=np.max(weights)
    w2 = np.exp(weights-maxw)
    
    plt.hist(lambda_sample,weights=w2,bins=np.linspace(2.5,2.8))
    plt.show()

def plotcomp(lam,mu,sig):
    x = np.linspace(a,b,40) 
    plt.hist(sizes,40,log=True,density=True)
    plt.plot(x,powerlaw(x,lam))
    plt.plot(x,lognormal(x,mu,sig))
    plt.show()
