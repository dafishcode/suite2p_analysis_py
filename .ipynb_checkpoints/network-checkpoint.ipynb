# %%
import sys
import network as netfn
import seaborn as sns
import os
import glob
from matplotlib import pyplot as plt
import numpy as np
import plot as pltfn
from sklearn.cluster import KMeans
plt.style.use('dark_background')
# %load_ext autoreload
# %autoreload

# Define paths
#---------------------------------------------------------------------------
Fdrop = '/Users/dominicburrows/Dropbox/PhD/analysis/'
Fmac = '/Users/dominicburrows/Documents/'
F10t = '/Volumes/Dominic 10tb/'
Ffig = '/Users/dominicburrows/Dropbox/PhD/figures/'
Ftm = '/Volumes/Dominic Time Machine/'

# %%
# Create coordlist 
#IF kcoord file exists & has 5 columns - already clustered!
#---------------------------------------------------------------------------
experiment = 'PTZ-WILDTYPE'
os.chdir(Fdrop + 'Project/' + experiment)
coordlist = sorted(glob.glob('*realcoord.npy'))
tracelist = sorted(glob.glob('*realtrace.npy'))
ktrace = sorted(glob.glob('*ktrace.npy'))
kcoord = sorted(glob.glob('*kcoord.npy'))
kcoord

# %% [markdown]
# # Node parcellation

# %%
# Run k-mean clustering on x-y coordinates to get spatially contiguous seed clusters
#Re-saves coordinate file with spacek labels as new columns (realcoord, 4columns: x,y,z,spacek labels)
#-----------------------------------------------------------------------------------------
kmeans = netfn.spacek(coordlist, Fdrop, experiment, mcc = 10)
# Out:
# Clustering fish 1 of 1

# %%
# Plot an illustrative example
#----------------------------------------------------------------------------------------
fish = 0
# Pull out the data from fish structure
#----------------------------------------------------------------------------------------
cs = np.load(coordlist[fish])
x = cs[:,0]
y = cs[:,1]
# Actual plotting routines
#----------------------------------------------------------------------------------------
plt.figure(figsize = (10,10))
plt.scatter(x, y, s = 7, c = cs[:,3],  cmap = 'Spectral', alpha = 1)
plt.show()

# %% [markdown]
# ## Functional clusters

# %%
# Calculate average traces within clusters
# Saves - array of traces for each spatial cluster (ktrace) and 
# mean coords for each cluster(kcoords, 3columns: x,y,z)
#---------------------------------------------------------------------------------------------------
Fktrace, Fkcoord  = netfn.average(Fdrop, experiment, tracelist, coordlist)
# Out:
# Calculating fish 1 of 1

# %%
# Plot an example traces
#----------------------------------------------------------------------------------------------
nplt  = 10
fish = 1
d     = np.load(ktrace[0])[:nplt,:2000]
cm    = plt.get_cmap("Paired")

plt.figure(figsize=(15,15))
for i in range(nplt):
    plt.plot(d[i,:] + 1500*i, c=cm(1))

# %%
# Plot correlation spatial clusters and functional/spatial clusters
#---------------------------------------------------------------------------------
fish = 2
cor = np.corrcoef(np.load(ktrace[fish])) #correlation matrix of each spatial cluster
kmeans   = KMeans(n_clusters=100, random_state=0).fit(cor) #spatial clusters clustered on functional correlation
kl       = kmeans.labels_ #new labels for functional clusters
klstd   = np.argsort(kl) #returns indices that would sort each spatial cluster into new cluster
scor    = cor[klstd,:]
scor    = scor[:,klstd] #re-order correlation matrix
fig, ax = plt.subplots(1,2, figsize= (15,10))
ax[0].matshow(cor, cmap='RdBu_r')
ax[1].matshow(scor, cmap='RdBu_r')
plt.show()

# %%
# Run K-means clustering on correlation matrix
#Re-saves - kcoord file by appending functional cluster labels 
#(4columns: x,y,z, corr cluster label, correlation cluster label)
#-----------------------------------------------------------
Fkcorr = netfn.funck(Fdrop, experiment, ktrace, kcoord)
# Out:
# Clustering fish 1 of 1

# %%
# Split up clusters according to spatial parameters
#Re-saves - kcoord file by appending functional cluster labels
#(5columns: x,y,z, corr cluster label, re-assigned corr cluster label)
#-----------------------------------------------------------------------
for i in range(len(kcoord)):
    kread = np.load(kcoord[i])
    nkl = divconq(kcoord, i, Fdrop, experiment, kcoord[i], kread)
    newclusterar = np.column_stack((kread[:,:4],nkl))
    np.save(Fdrop + 'Project/' + experiment + os.sep + kcoord[i][:kcoord[i].find('run')+6] + '_kcoord.npy', newclusterar)

# %%
np.load(coordlist[0])[:,:3]
# Out:
# array([[264., 227.,   0.],
#        [233., 113.,   0.],
#        [272., 158.,   0.],
#        ...,
#        [488., 233.,   9.],
#        [153., 219.,   9.],
#        [348., 229.,   9.]])

# %%
lb.shape
# Out:
# (8657, 1)

# %%
ks
# Out:
# array([26., 33., 90., 48., 46., 23., 16., 79., 27., 64., 58., 26., 40.,
#        27., 91., 34., 69., 93., 10., 92., 91., 64., 82., 30., 53., 99.,
#        31., 31.,  5., 63., 30., 34., 28., 94., 12., 19., 23., 30.,  8.,
#        38., 49., 66., 28., 54.,  2., 40., 58., 94., 43., 91., 53., 37.,
#        45., 71., 91., 29.,  6.,  7., 34., 70., 16., 44., 58., 92., 52.,
#        36.,  2., 92., 62., 21., 66., 77., 20., 50., 66., 39., 24., 99.,
#        20., 17., 74., 44.,  8., 75., 38., 10., 54., 81., 61., 70., 67.,
#        45., 51., 50., 63., 45., 20., 84., 64., 41., 92., 86., 11., 39.,
#        54., 79., 12., 27., 66.,  7., 60., 34., 64.,  3., 65., 42., 94.,
#        85., 75., 69., 85., 52., 26., 80., 62., 50., 16.,  6., 27., 78.,
#        60., 21., 56., 88., 94., 61., 16., 10., 27., 32., 72., 10., 33.,
#        97., 79., 89., 36., 42., 76., 37., 61., 86., 27., 82., 68., 23.,
#        65., 56., 48., 14., 70., 96.,  3., 86., 50., 36., 16., 78., 99.,
#        62., 96.,  3., 42., 71., 44., 39.,  7., 49., 79.,  6., 78., 56.,
#        56., 13., 91., 16., 66., 60., 52., 19., 23., 21., 38., 97., 33.,
#        28., 29., 38., 92., 76., 81., 12., 26., 48., 69., 43., 22.,  5.,
#        68., 54., 45., 34., 29., 62.,  8., 15., 58., 94., 77., 17., 90.,
#        79., 58., 38., 14., 12., 45., 77., 18., 46., 33., 46., 19., 33.,
#        97., 94., 87., 22., 17.,  0., 79., 14., 96., 15., 82., 10., 91.,
#        45., 78., 97., 62., 30., 70., 94., 83., 37., 37., 66.,  8., 34.,
#         4., 65., 35., 35., 34., 35., 14., 23., 85., 20., 48., 10., 93.,
#        84., 10., 34., 21., 89., 22.,  5., 81.,  2., 14., 74., 53., 66.,
#        29., 28.,  1., 58., 19., 22., 36.,  6., 79., 88.,  9., 10., 33.,
#         6., 17., 27., 51., 36., 21., 44., 20., 11., 18., 88., 81., 67.,
#        39., 23.,  7., 30., 85., 23., 60.,  6., 13., 90.,  6., 54., 78.,
#        78., 55., 18., 22., 23., 86., 74., 12.,  9., 77.,  5., 60., 20.,
#         4.,  6., 40., 73., 78., 39., 22., 35.,  1., 98., 82., 33., 16.,
#        31., 43., 21.,  2., 83., 68., 74., 68., 42., 59., 78., 12., 75.,
#         1., 94., 75., 36., 10.,  5.,  9., 80., 88., 11.,  6., 19., 69.,
#        59., 59., 68., 12., 78., 17., 55., 88.,  1., 76., 20., 23., 16.,
#        29., 13., 73., 55., 81., 46., 66., 98., 54., 98., 40., 27., 21.,
#        36., 24., 67., 43., 62., 34., 23., 65., 67., 79., 23., 71., 74.,
#        23., 23., 57.,  3., 49., 98., 40.])

# %%
i = 0

# %%
np.int(ks[i])
# Out:
# 26

# %%
ksredo[np.int(ks[i])]
# Out:
# 128.0

# %%
ksredo[int(ks[i])]
# Out:
# 128.0

# %%
# Re-average traces according to new parcel labels
#-----------------------------------------------------------------------
cs = np.load(coordlist[0])[:,:3] #single neuron coordinates
ks = np.load(kcoord[0])[:,3] #cluster labels

# Average within label groups
#----------------------------------------------------------------------
md,ml,mloc = netfn.average(Fish["Filt"], lb, cs)
#Ps = ({"Label":ps, "Coordinates":mloc, "Data":md})
#Fish.update({"Parcels":Ps})

# %%
# Plot new categorisation
#-----------------------------------------------------------------------
fine_cs      = Fish["Coordinates"]
crse_cs      = Fish["Parcels"]["Coordinates"]
ks           = Fish["Klabel"]
fine_lb      = np.zeros((fine_cs.shape[0],1))
crse_lb      = np.zeros((crse_cs.shape[0],1))

for i in range(fine_cs.shape[0]): fine_lb[i] = ps[int(ks[i])]
for i in range(crse_cs.shape[0]): crse_lb[i] = Fish["Parcels"]["Label"][i]
    

cci    = np.where(Fish["Parcels"]["Coordinates"][:,2] == plane) 

# Actual plotting routines
#----------------------------------------------------------------------------------------
plane  = 5
fci    = Fish["Planes"][plane]["Index"]  
f, ax1 = plt.subplots(1, 1, sharey=True, figsize=(10,10))
ax1.scatter(fine_cs[fci,0], fine_cs[fci,1], s = 20, c = 'gray', cmap = 'Set1')
ax1.scatter(crse_cs[:,0], crse_cs[:,1], s = 250, c = crse_lb[:,0], cmap = 'Set1')

# %%
# Plot example module traces
#---------------------------------------------------------------------------------------
plt.figure(figsize=(15,10))
plt.matshow(Fish["Parcels"]["Data"][:400,:1000], cmap='magma')
Fish["Parcels"]["Data"][:400,:1000].shape

# %% [markdown]
# ## Module detection

# %%
# Convert matrix into NetworkX Graph object to run module detection
#-------------------------------------------------------------------------------------
cor        = np.corrcoef(Fish["Parcels"]["Data"]); 
cor[cor < 0] = 0
G          = nx.from_numpy_array(cor)
partition  = community.best_partition(G)
M          = {"Label":np.asarray(partition.values())}
Fish.update({"Modules":M})
